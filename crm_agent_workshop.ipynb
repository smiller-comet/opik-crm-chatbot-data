# %% [markdown]
# # CRM Agent Workshop
#
# ## Setup & Configuration

# %%
# %pip install --upgrade --quiet opik openai

# %%
import opik
opik.configure(use_local=False)

# %%
import os
import getpass

PROJECT_NAME = "CRM-Chatbot-Agent-Opik"
os.environ["PROJECT_NAME"] = PROJECT_NAME

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## Load Historical CRM Agent Traces

# %%
# !wget -q https://raw.githubusercontent.com/smiller-comet/opik-crm-chatbot-data/main/workshop_traces_data.json
# !wget -q https://raw.githubusercontent.com/smiller-comet/opik-crm-chatbot-data/main/workshop_spans_data.json
# !wget -q https://raw.githubusercontent.com/smiller-comet/opik-crm-chatbot-data/main/workshop_trace_ingestion.py

# !python workshop_trace_ingestion.py
